# %%
require(stats); require(graphics)
X=as.matrix(longley[,1:6])
y=as.matrix(longley[,7])
library(car)
## give the data set in the form it is used in S-PLUS:
longley.x <- data.matrix(scale(longley[, 1:6]))
longley.y <- scale(longley[, "Employed"])
pairs(longley, main = "longley data")
summary(fm1 <- lm(Employed ~ ., data = as.data.frame(scale(longley))))
opar <- par(mfrow = c(2, 2), oma = c(0, 0, 1.1, 0),
            mar = c(4.1, 4.1, 2.1, 1.1))
plot(fm1)
par(opar)
# Out:
# Call:
# lm(formula = Employed ~ ., data = as.data.frame(scale(longley)))
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.116776 -0.044896 -0.008019  0.028916  0.129669
#
# Coefficients:
#                Estimate Std. Error t value Pr(>|t|)
# (Intercept)  -1.752e-15  2.170e-02   0.000 1.000000
# GNP.deflator  4.628e-02  2.609e-01   0.177 0.863141
# GNP          -1.014e+00  9.479e-01  -1.070 0.312681
# Unemployed   -5.375e-01  1.300e-01  -4.136 0.002535 **
# Armed.Forces -2.047e-01  4.246e-02  -4.822 0.000944 ***
# Population   -1.012e-01  4.478e-01  -0.226 0.826212
# Year          2.480e+00  6.175e-01   4.016 0.003037 **
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 0.0868 on 9 degrees of freedom
# Multiple R-squared:  0.9955,	Adjusted R-squared:  0.9925
# F-statistic: 330.3 on 6 and 9 DF,  p-value: 4.984e-10
# plot without title
# Plot with title ""

# %% [markdown]
# ## 第一问：检查复共线性

# %%
#先将X中心标准化
(X=scale(X))
# Out:
#      GNP.deflator GNP        Unemployed Armed.Forces Population   Year
# 1947 -1.73109925  -1.5434331 -0.8960348 -1.46092666  -1.411135233 -1.5753151
# 1948 -1.22144139  -1.2905329 -0.9292089 -1.65347763  -1.263926342 -1.3652731
# 1949 -1.24924091  -1.3043364  0.5229601 -1.42356602  -1.099897684 -1.1552311
# 1950 -1.12877633  -1.0372705  0.1687464 -1.37470980  -0.933712647 -0.9451891
# 1951 -0.50792039  -0.5908091 -1.1710587  0.70742726  -0.768965196 -0.7351470
# 1952 -0.33185676  -0.4094719 -1.3497707  1.41871632  -0.597173570 -0.5251050
# 1953 -0.24845821  -0.2244927 -1.4161189  1.35117978  -0.334957732 -0.3150630
# 1954 -0.15579314  -0.2473611  0.4116664  1.06810111  -0.173229213 -0.1050210
# 1955 -0.04459506   0.0983004 -0.3096025  0.63414293  -0.005175313  0.1050210
# 1956  0.27046616   0.3167321 -0.3973534  0.35968594   0.188323875  0.3150630
# 1957  0.62259341   0.5540580 -0.2753583  0.27490604   0.434294982  0.5251050
# 1958  0.84498956   0.5719362  1.5920219  0.04355747   0.650651800  0.7351470
# 1959  1.01178668   0.9558390  0.6631474 -0.07858307   0.854214095  0.9451891
# 1960  1.16005078   1.1560203  0.7894229 -0.13318708   1.142018979  1.1552311
# 1961  1.29904838   1.3126882  1.7257883 -0.04984412   1.499115547  1.3652731
# 1962  1.41024646   1.6821336  0.8707530  0.31657752   1.819553652  1.5753151

# %% [markdown]
# 条件数：程度小  100  较强  1000  严重

# %%
kappa(t(X)%*%X,exact=T)
# Out:
# [1] 12220.01

# %% [markdown]
# 方差扩大因子法：不存在  10  较强   100    严重

# %%
vif(fm1)
# Out:
# GNP.deflator          GNP   Unemployed Armed.Forces   Population         Year
#    135.53244   1788.51348     33.61889      3.58893    399.15102    758.98060

# %% [markdown]
# 绘图

# %%
library(corrplot)
corrplot.mixed(cor(X))
# Out:
# corrplot 0.92 loaded
# Plot with title ""

# %% [markdown]
# ## 第二问：主成分估计

# %%
(phi=eigen(t(X)%*%X)$vectors)
(gam=diag(eigen(t(X)%*%X)$values))
(Z=X%*%phi)
# Out:
#      [,1]       [,2]          [,3]       [,4]         [,5]         [,6]
# [1,] -0.4618349  0.0578427677  0.1491199  0.792873559 -0.337937826  0.13518707
# [2,] -0.4615043  0.0532122862  0.2776823 -0.121621225  0.149573192 -0.81848082
# [3,] -0.3213167 -0.5955137627 -0.7283057  0.007645795 -0.009231961 -0.10745268
# [4,] -0.2015097  0.7981925480 -0.5616075 -0.077254979 -0.024252472 -0.01797096
# [5,] -0.4622794 -0.0455444698  0.1959846 -0.589744965 -0.548578173  0.31157087
# [6,] -0.4649403  0.0006187884  0.1281157 -0.052286554  0.749542836  0.45040888
#      [,1]     [,2]     [,3]     [,4]      [,5]       [,6]
# [1,] 69.05066  0.00000 0.000000 0.0000000 0.00000000 0.000000000
# [2,]  0.00000 17.63011 0.000000 0.0000000 0.00000000 0.000000000
# [3,]  0.00000  0.00000 3.051381 0.0000000 0.00000000 0.000000000
# [4,]  0.00000  0.00000 0.000000 0.2239239 0.00000000 0.000000000
# [5,]  0.00000  0.00000 0.000000 0.0000000 0.03828099 0.000000000
# [6,]  0.00000  0.00000 0.000000 0.0000000 0.00000000 0.005650622
#      [,1]        [,2]       [,3]        [,4]         [,5]         [,6]
# 1947  3.47885116 -0.7514663  0.30794582 -0.164237941 -0.008797212  0.002579214
# 1948  3.01051050 -0.8490405  0.64223117  0.125922070 -0.061546790  0.011980162
# 1949  2.34330004 -1.5399966 -0.49343353 -0.008816911 -0.005746265  0.005060099
# 1950  2.09390207 -1.2763204 -0.11129318 -0.061256404  0.061845300 -0.013676557
# 1951  1.43823979  1.2357941 -0.02909527  0.097463990 -0.052256066 -0.042681983
# 1952  1.01025833  1.9221044 -0.16121665  0.046393092 -0.037037746 -0.012750887
# 1953  0.70242732  1.9105632  0.06713593 -0.070892392 -0.021713287  0.031768151
# 1954 -0.03249036  0.5930479 -1.03899732 -0.065156276  0.002257254  0.016694040
# 1955 -0.09951208  0.6934927 -0.09756732 -0.101110590  0.098808975 -0.018924288
# 1956 -0.44943161  0.5478444  0.29294826  0.017561897  0.083761817  0.014140615
# 1957 -0.95506265  0.4294480  0.44523825  0.119330230  0.023693277  0.027154014
# 1958 -1.81709954 -0.8631718 -0.67741782  0.187060615 -0.021670650  0.008103978
# 1959 -1.93998935 -0.3865707  0.26596237  0.143920673  0.036687067 -0.023530423
# 1960 -2.36112184 -0.4991039  0.36567210  0.061599130  0.016235281  0.004357521
# 1961 -3.07801835 -0.9899558 -0.20196785 -0.068105173 -0.056429600 -0.001328554
# 1962 -3.34476344 -0.1766686  0.42385505 -0.259676010 -0.058091355 -0.008945102

# %%
(gam[1,1]/sum(diag(gam)))
((gam[1,1]+gam[2,2])/sum(diag(gam)))
# Out:
# [1] 0.7672295
# [1] 0.9631196

# %% [markdown]
# 于是选前两个主成分

# %%
(Z1=X%*%phi[,1:2])
# Out:
#      [,1]        [,2]
# 1947  3.47885116 -0.7514663
# 1948  3.01051050 -0.8490405
# 1949  2.34330004 -1.5399966
# 1950  2.09390207 -1.2763204
# 1951  1.43823979  1.2357941
# 1952  1.01025833  1.9221044
# 1953  0.70242732  1.9105632
# 1954 -0.03249036  0.5930479
# 1955 -0.09951208  0.6934927
# 1956 -0.44943161  0.5478444
# 1957 -0.95506265  0.4294480
# 1958 -1.81709954 -0.8631718
# 1959 -1.93998935 -0.3865707
# 1960 -2.36112184 -0.4991039
# 1961 -3.07801835 -0.9899558
# 1962 -3.34476344 -0.1766686

# %% [markdown]
# 其最小二乘估计为：

# %%
(alph0=mean(y))
(alph1=solve(t(Z1)%*%Z1)%*%t(Z1)%*%y)
# Out:
# [1] 65.317
#      [,1]
# [1,] -1.5651125
# [2,]  0.3918278

# %%
(beta1=phi[,1:2]%*%alph1)
# Out:
#      [,1]
# [1,] 0.7454880
# [2,] 0.7431563
# [3,] 0.2695580
# [4,] 0.6281394
# [5,] 0.7056736
# [6,] 0.7279263

# %% [markdown]
# 用自带的函数写为：

# %%
PCA=princomp(X)
summary(PCA,loadings=T)
screeplot(PCA,type="lines")
# Out:
# Importance of components:
#                           Comp.1    Comp.2     Comp.3      Comp.4       Comp.5
# Standard deviation     2.0774181 1.0497055 0.43670503 0.118301490 0.0489138186
# Proportion of Variance 0.7672295 0.1958901 0.03390423 0.002488043 0.0004253443
# Cumulative Proportion  0.7672295 0.9631196 0.99702383 0.999511871 0.9999372153
#                              Comp.6
# Standard deviation     1.879265e-02
# Proportion of Variance 6.278469e-05
# Cumulative Proportion  1.000000e+00
#
# Loadings:
#              Comp.1 Comp.2 Comp.3 Comp.4 Comp.5 Comp.6
# GNP.deflator  0.462         0.149  0.793  0.338  0.135
# GNP           0.462         0.278 -0.122 -0.150 -0.818
# Unemployed    0.321 -0.596 -0.728               -0.107
# Armed.Forces  0.202  0.798 -0.562
# Population    0.462         0.196 -0.590  0.549  0.312
# Year          0.465         0.128        -0.750  0.450
# Plot with title "PCA"

# %%
#这个不知道干啥用的
source("mvstats.R")
princomp.rank(PCA,m=2)
princomp.rank(PCA,m=2,plot=T)
# Out:
#      Comp.1      Comp.2     PC         rank
# 1947 -3.47885116 -0.7514663 -2.9241250  1
# 1948 -3.01051050 -0.8490405 -2.5708865  2
# 1949 -2.34330004 -1.5399966 -2.1799152  3
# 1950 -2.09390207 -1.2763204 -1.9276131  4
# 1951 -1.43823979  1.2357941 -0.8943647  5
# 1952 -1.01025833  1.9221044 -0.4138414  6
# 1953 -0.70242732  1.9105632 -0.1709680  7
# 1954  0.03249036  0.5930479  0.1465028  8
# 1955  0.09951208  0.6934927  0.2203225  9
# 1956  0.44943161  0.5478444  0.4694479 10
# 1957  0.95506265  0.4294480  0.8481572 11
# 1958  1.81709954 -0.8631718  1.2719558 12
# 1959  1.93998935 -0.3865707  1.4667874 13
# 1960  2.36112184 -0.4991039  1.7793770 14
# 1961  3.07801835 -0.9899558  2.2506281 15
# 1962  3.34476344 -0.1766686  2.6285350 16
#      Comp.1      Comp.2     PC         rank
# 1947 -3.47885116 -0.7514663 -2.9241250  1
# 1948 -3.01051050 -0.8490405 -2.5708865  2
# 1949 -2.34330004 -1.5399966 -2.1799152  3
# 1950 -2.09390207 -1.2763204 -1.9276131  4
# 1951 -1.43823979  1.2357941 -0.8943647  5
# 1952 -1.01025833  1.9221044 -0.4138414  6
# 1953 -0.70242732  1.9105632 -0.1709680  7
# 1954  0.03249036  0.5930479  0.1465028  8
# 1955  0.09951208  0.6934927  0.2203225  9
# 1956  0.44943161  0.5478444  0.4694479 10
# 1957  0.95506265  0.4294480  0.8481572 11
# 1958  1.81709954 -0.8631718  1.2719558 12
# 1959  1.93998935 -0.3865707  1.4667874 13
# 1960  2.36112184 -0.4991039  1.7793770 14
# 1961  3.07801835 -0.9899558  2.2506281 15
# 1962  3.34476344 -0.1766686  2.6285350 16
# plot without title

# %% [markdown]
# ## 第三问：岭回归

# %%
betahat <- function(k){
    return (solve(t(X)%*%X+k*diag(6))%*%t(X)%*%y)
}

# %% [markdown]
# 岭迹法

# %%
library("MASS")
plot(lm.ridge(Employed~.,as.data.frame(scale(longley)),lambda = seq(0,0.3,0.001)))
abline(v=0.05)
# Out:
# plot without title

# %% [markdown]
# H-K公式

# %%
(alphhat=solve(gam)%*%t(Z)%*%y)

(sig2hat=(t(y-Z%*%alphhat-(rep(alph0,length(y))))%*%(y-Z%*%alphhat-(rep(alph0,length(y)))))/10)
# Out:
#      [,1]
# [1,] -1.5651125
# [2,]  0.3918278
# [3,]  1.8603865
# [4,]  0.3572996
# [5,]  6.1698284
# [6,]  6.9633685
#      [,1]
# [1,] 0.08364241

# %%
sighat^2/(max(alphhat^2))
# Out:
#      [,1]
# [1,] 0.0001442827

# %% [markdown]
# 方差膨胀因子法：
# https://blog.csdn.net/weixin_36245388/article/details/112481767?spm=1001.2101.3001.6650.3&utm_medium=distribute.pc_relevant.none-task-blog-2%7Edefault%7ECTRLIST%7ERate-3-112481767-blog-104657790.pc_relevant_3mothn_strategy_recovery&depth_1-utm_source=distribute.pc_relevant.none-task-blog-2%7Edefault%7ECTRLIST%7ERate-3-112481767-blog-104657790.pc_relevant_3mothn_strategy_recovery&utm_relevant_index=6

# %%
chat <- function(k){
    return (max(diag(solve(t(Z)%*%Z+diag(k,6))%*%t(Z)%*%(Z)%*%solve(t(Z)%*%Z+diag(k,6)))))
}

# %%
ys=c()
for (i in seq(0.01,0.2,0.001)){
    ys=append(ys,chat(i))
}
plot(seq(0.01,0.2,0.001),ys)
abline(h=10)
# Out:
# plot without title
