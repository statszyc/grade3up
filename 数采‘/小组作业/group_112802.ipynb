# %%
import numpy as np
import pandas as pd
df=pd.read_excel('题目文本.xlsx',na_values=['(跳过)'])
df['来自IP']=df['来自IP'].map(lambda x: x[x.find('(')+1:x.find('-')])

# %% [markdown]
# # value_counts画图分析

# %%
df['2、您在双11期间的消费金额为：'].value_counts() #value_counts自动skip_na的优势
# Out:
# 大于等于200元且小于500元      45
# 大于等于500元且小于1000元     43
# 大于等于1000元且小于3000元    31
# 大于等于100元且小于200元      25
# 小于100元               22
# 大于等于3000元             8
# Name: 2、您在双11期间的消费金额为：, dtype: int64

# %%
df['27、您的学科具体属于法学学科下的哪个专业分类呢？'].value_counts()
# Out:
# 法学类         6
# 马克思主义理论类    2
# 政治学类        1
# Name: 27、您的学科具体属于法学学科下的哪个专业分类呢？, dtype: int64

# %%
df.columns
# Out:
# Index(['序号', '提交答卷时间', '所用时间', '来源', '来源详情', '来自IP', '1、双11的购物意愿',
#        '2、您在双11期间的消费金额为：', '3、您在双11期间购买的商品个数', '4、您平时每月在网络上总体的消费情况为：',
#        '5、您平时每月网购的商品个数', '6、您每月包括生活费在内的收入为：', '7、您经常购买哪些类型的商品',
#        '8、您消费的原因主要有哪些', '9、为确保本问卷的有效性，本题请选C', '10、您对香菜的态度是？',
#        '11、您在双11期间是否有过冲动消费行为？', '12、您双11期间冲动消费所购买的商品有什么类型的呢？',
#        '13、请问是什么原因促使您购买了上题提到的商品？', '14、您在双11期间的冲动性消费后出现过以下的哪些情况呢？',
#        '15、您双11期间的冲动消费行为发生在了哪些价格区间', '16、您平时冲动消费频率是', '17、您发朋友圈的频率为？',
#        '18、您平时冲动消费所购买的商品有什么类型的呢？', '19、请问是什么原因促使您购买了上题提到的商品？',
#        '20、您平时在冲动性消费后出现过以下的哪些情况呢？', '21、您一般如何处理这些不常使用的商品？',
#        '22、您的冲动消费行为常常发生在哪些价格区间', '23、您的性别：', '24、您的在读学历：', '25、您目前就读的专业属于：',
#        '26、您的学科具体属于理学学科下的哪个专业分类呢？', '27、您的学科具体属于法学学科下的哪个专业分类呢？',
#        '28、您的学科具体属于工学学科下的哪个专业分类呢？', '29、您的学科具体属于文学学科下的哪个专业分类呢？',
#        '30、您的学科具体属于经济学学科下的哪个专业分类呢？', '31、您的学科具体属于管理学学科下的哪个专业分类呢？',
#        '32、下列哪项更符合您的书桌情况：'],
#       dtype='object')

# %%
df['9、为确保本问卷的有效性，本题请选C'].value_counts()
# Out:
# C    196
# Name: 9、为确保本问卷的有效性，本题请选C, dtype: int64

# %%
test=df['12、您双11期间冲动消费所购买的商品有什么类型的呢？'][2]

# %%
sep='┋'
test.split(sep)
all_item=sum(df['12、您双11期间冲动消费所购买的商品有什么类型的呢？'].fillna('nan').map(lambda x : x.split(sep)).values,[])
pd.DataFrame(all_item).value_counts()[1:]
# Out:
# 化妆品             25
# 衣物              25
# 电子产品            24
# 日用品             23
# 食品              18
# 娱乐产品（玩具、手办等）    12
# 书籍              10
# 游戏或软件充值          8
# 家用电器             7
# 首饰               6
# 文具               4
# 体验与服务            3
# 药品               2
# dtype: int64

# %%
df
# Out:
#       序号               提交答卷时间  所用时间    来源  来源详情 来自IP 1、双11的购物意愿  \
# 0      4   2022/11/25 9:43:09  156秒    微信   NaN   天津      较高于平时
# 1      5   2022/11/25 9:50:42  152秒    微信   NaN   天津     没有消费意愿
# 2      6   2022/11/25 9:54:29  401秒    微信   NaN   北京      远高于平时
# 3      7   2022/11/25 9:56:14   62秒    微信   NaN   天津      与平时持平
# 4      8   2022/11/25 9:57:30  355秒    微信   NaN   天津     没有消费意愿
# ..   ...                  ...   ...   ...   ...  ...        ...
# 191  195  2022/11/27 18:14:36   97秒  手机提交  直接访问   天津      较高于平时
# 192  196  2022/11/27 18:15:39   56秒  手机提交  直接访问   天津      与平时持平
# 193  197  2022/11/27 18:18:30  166秒  手机提交  直接访问   天津     甚至不如平时
# 194  198  2022/11/27 18:23:28  276秒  手机提交  直接访问   天津      与平时持平
# 195  199  2022/11/27 18:34:44  404秒  手机提交  直接访问   天津      远高于平时
#
#      2、您在双11期间的消费金额为： 3、您在双11期间购买的商品个数 4、您平时每月在网络上总体的消费情况为：  ... 23、您的性别：  \
# 0              小于100元             小于5个      大于等于100元且小于200元  ...        男
# ...

# %%
num=len(df)
num
# Out:
# 196

# %%
#用时
time_take=[]
for i in range(num):
    time_take.append(int(df['所用时间'][i][:-1]))
df["填写时间"]=time_take
df=df.drop('所用时间',axis=1)
print(min(time_take),max(time_take))
# Out:
# 54 731

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.cm as cm 
# 汉字字体，优先使用楷体，找不到则使用黑体
plt.rcParams['font.sans-serif'] = ['Kaitt', 'SimHei']
 
# 正常显示负号
plt.rcParams['axes.unicode_minus'] = False

# %%
fig = plt.figure()
axes1 = fig.add_subplot(1, 1, 1)
axes1.hist(df["填写时间"], bins=20,facecolor='wheat')
plt.title("用时频数")
plt.show()

# %%
#双十一意愿
col='1、双11的购物意愿'
colors = ['wheat', 'orange', 'gold', 'khaki','darkkhaki']
plt.pie(df[col].value_counts(), labels=df[col].value_counts().index, colors=colors,autopct='%3.3f%%')  #以时间为标签，总计成交笔数为数据绘制饼图，并显示3位整数一位小数
plt.title('双11的购物意愿') 

plt.show()

# %%
#双十一金额
col='2、您在双11期间的消费金额为：'
colors = ['wheat', 'orange', 'gold', 'khaki','darkkhaki','olive']
plt.pie(df[col].value_counts(), labels=df[col].value_counts().index, colors=colors,autopct='%3.3f%%') 
plt.title('双11的消费金额') 

plt.show()

# %%
#商品个数
col='3、您在双11期间购买的商品个数'
colors = ['wheat', 'orange', 'gold', 'khaki','darkkhaki','olive']
plt.pie(df[col].value_counts(), labels=df[col].value_counts().index, colors=colors,autopct='%3.3f%%') 
plt.title('双11购买的商品个数') 

plt.show()

# %%
#平时金额
col='4、您平时每月在网络上总体的消费情况为：'
colors = ['wheat', 'orange', 'gold', 'khaki','darkkhaki','olive']
plt.pie(df[col].value_counts(), labels=df[col].value_counts().index, colors=colors,autopct='%3.3f%%') 
plt.title('平时每月网购消费金额') 

plt.show()

# %%
#平时商品个数
col='5、您平时每月网购的商品个数'
colors = ['wheat', 'orange', 'gold', 'khaki','darkkhaki','olive']
plt.pie(df[col].value_counts(), labels=df[col].value_counts().index, colors=colors,autopct='%3.3f%%') 
plt.title('平时每月购买的商品个数') 

plt.show()

# %%
pd.Series(all_item).value_counts().index
# Out:
# Index(['nan', '化妆品', '衣物', '电子产品', '日用品', '食品', '娱乐产品（玩具、手办等）', '书籍',
#        '游戏或软件充值', '家用电器', '首饰', '文具', '体验与服务', '药品'],
#       dtype='object')

# %%
sep='┋'
test.split(sep)
all_item=sum(df['7、您经常购买哪些类型的商品'].fillna('nan').map(lambda x : x.split(sep)).values,[])
print(pd.DataFrame(all_item).value_counts()[1:])
fig = plt.figure()
axes1 = fig.add_subplot(1, 1, 1)
axes1.bar(pd.Series(all_item).value_counts().index,pd.Series(all_item).value_counts().values,color=colors)
plt.xticks(rotation=90,fontsize=9)
plt.title("经常购买各项商品的人数")
plt.show()
# Out:
# 食品              127
# 衣物               96
# 书籍               83
# 电子产品             65
# 文具               51
# 游戏或软件充值          51
# 化妆品              47
# 娱乐产品（玩具、手办等）     38
# 首饰               28
# 药品               25
# 体验与服务            20
# 家用电器             20
# dtype: int64

# %%
sep='┋'
test.split(sep)
all_item=sum(df['8、您消费的原因主要有哪些'].fillna('nan').map(lambda x : x.split(sep)).values,[])
print(pd.DataFrame(all_item).value_counts()[1:])
fig = plt.figure()
axes1 = fig.add_subplot(1, 1, 1)
axes1.bar(pd.Series(all_item).value_counts().index,pd.Series(all_item).value_counts().values,color=colors)
plt.xticks(rotation=90,fontsize=9)
plt.title("消费原因—人数")
plt.show()
# Out:
# 价格合理          135
# 商品的图片或外形美观     70
# 个人的情绪因素        66
# 商品背后的文化因素      26
# 跟随潮流           14
# 与卖家认识           2
# dtype: int64

# %%
#平时是否冲动消费
col='11、您在双11期间是否有过冲动消费行为？'
colors = ['wheat', 'orange', 'gold', 'khaki','darkkhaki','olive']
plt.pie(df[col].value_counts(), labels=df[col].value_counts().index, colors=colors,autopct='%3.3f%%') 
plt.title('双11期间是否有过冲动消费行为') 

plt.show()

# %%
#双11冲动消费类型
sep='┋'
test.split(sep)
all_item=sum(df['12、您双11期间冲动消费所购买的商品有什么类型的呢？'].fillna('nan').map(lambda x : x.split(sep)).values,[])
print(pd.Series(all_item).value_counts()[1:])
fig = plt.figure()
axes1 = fig.add_subplot(1, 1, 1)
axes1.bar(pd.Series(all_item).value_counts().drop('nan').index,pd.Series(all_item).value_counts().drop('nan').values,color=colors)
plt.xticks(rotation=90,fontsize=9)
plt.title("双11冲动消费的商品类型")
plt.show()
# Out:
# 化妆品             25
# 衣物              25
# 电子产品            24
# 日用品             23
# 食品              18
# 娱乐产品（玩具、手办等）    12
# 书籍              10
# 游戏或软件充值          8
# 家用电器             7
# 首饰               6
# 文具               4
# 体验与服务            3
# 药品               2
# dtype: int64

# %%
#冲动消费原因
sep='┋'
test.split(sep)
all_item=sum(df['13、请问是什么原因促使您购买了上题提到的商品？'].fillna('nan').map(lambda x : x.split(sep)).values,[])
print(pd.DataFrame(all_item).value_counts()[1:])
fig = plt.figure()
axes1 = fig.add_subplot(1, 1, 1)
axes1.bar(pd.Series(all_item).value_counts().drop('nan').index,pd.Series(all_item).value_counts().drop('nan').values,color=colors)
plt.xticks(rotation=90,fontsize=9)
plt.title("双11冲动消费原因—人数")
plt.show()
# Out:
# 商品降价              56
# 以为能用得到            30
# 情绪因素              22
# 商品图片吸引眼球          14
# 大品牌或由名人代言，慕名已久    14
# 跟随潮流              13
# 亲朋推荐               6
# dtype: int64

# %%
#冲动后是否后悔
sep='┋'
test.split(sep)
all_item=sum(df['14、您在双11期间的冲动性消费后出现过以下的哪些情况呢？'].fillna('nan').map(lambda x : x.split(sep)).values,[])
print(pd.DataFrame(all_item).value_counts()[1:])
fig = plt.figure()
axes1 = fig.add_subplot(1, 1, 1)
axes1.bar(pd.Series(all_item).value_counts().drop('nan').index,pd.Series(all_item).value_counts().drop('nan').values,color=colors)
plt.xticks(rotation=90,fontsize=9)
plt.title("双11冲动消费后后悔")
plt.show()
# Out:
# 购买后与购买前的期望有差距                38
# 只用了比较短的时间，之后就不常使用，成为了闲置商品    37
# 以上情况均未出现过                    19
# 觉得买贵了                        18
# dtype: int64

# %%
#双11冲动消费区间
col='15、您双11期间的冲动消费行为发生在了哪些价格区间'
colors = ['wheat', 'orange', 'gold', 'khaki','darkkhaki','olive']
sep='┋'
test.split(sep)
all_item=sum(df[col].fillna('nan').map(lambda x : x.split(sep)).values,[])
print(pd.DataFrame(all_item).value_counts()[1:])
fig = plt.figure()
axes1 = fig.add_subplot(1, 1, 1)
plt.pie(pd.Series(all_item).value_counts().drop('nan').values, labels=pd.Series(all_item).value_counts().drop('nan').index, colors=colors,autopct='%3.3f%%') 
plt.title('双11期间发生的冲动消费行为所在价格区间') 

plt.show()
# Out:
# 大于等于100元且小于200元     29
# 大于等于200元且小于500元     28
# 大于等于500元且小于1000元    18
# 小于100元              18
# 大于等于1000元            9
# dtype: int64

# %%
#平时冲动消费频率
col='16、您平时冲动消费频率是'
colors = ['wheat', 'orange', 'gold', 'khaki','darkkhaki','olive']
plt.pie(df[col].value_counts(), labels=df[col].value_counts().index, colors=colors,autopct='%3.3f%%') 
plt.title('平时冲动消费频率') 

plt.show()

# %%
#平时冲动消费类型
sep='┋'
test.split(sep)
all_item=sum(df['18、您平时冲动消费所购买的商品有什么类型的呢？'].fillna('nan').map(lambda x : x.split(sep)).values,[])
print(pd.Series(all_item).value_counts()[1:])
fig = plt.figure()
axes1 = fig.add_subplot(1, 1, 1)
axes1.bar(pd.Series(all_item).value_counts().drop('nan').index,pd.Series(all_item).value_counts().drop('nan').values,color=colors)
plt.xticks(rotation=90,fontsize=9)
plt.title("平时冲动消费的商品类型")
plt.show()
# Out:
# 游戏或软件充值         55
# 电子产品            52
# 食品              49
# 娱乐产品（玩具、手办等）    46
# 日用品             40
# 化妆品             38
# 书籍              30
# nan             25
# 首饰              20
# 体验与服务           13
# 文具              11
# 家用电器             7
# 药品               3
# dtype: int64

# %%
#平时冲动消费原因
sep='┋'
test.split(sep)
all_item=sum(df['19、请问是什么原因促使您购买了上题提到的商品？'].fillna('nan').map(lambda x : x.split(sep)).values,[])
print(pd.DataFrame(all_item).value_counts()[1:])
fig = plt.figure()
axes1 = fig.add_subplot(1, 1, 1)
axes1.bar(pd.Series(all_item).value_counts().drop('nan').index,pd.Series(all_item).value_counts().drop('nan').values,color=colors)
plt.xticks(rotation=90,fontsize=9)
plt.title("平时冲动消费原因—人数")
plt.show()
# Out:
# 以为能用得到            78
# 情绪因素              64
# 商品图片吸引眼球          42
# nan               25
# 大品牌或由名人代言，慕名已久    24
# 跟随潮流              16
# 亲朋推荐              13
# dtype: int64

# %%
#平时冲动后是否后悔
sep='┋'
test.split(sep)
all_item=sum(df['20、您平时在冲动性消费后出现过以下的哪些情况呢？'].fillna('nan').map(lambda x : x.split(sep)).values,[])
print(pd.DataFrame(all_item).value_counts()[1:])
fig = plt.figure()
axes1 = fig.add_subplot(1, 1, 1)
axes1.bar(pd.Series(all_item).value_counts().drop('nan').index,pd.Series(all_item).value_counts().drop('nan').values,color=colors)
plt.xticks(rotation=90,fontsize=9)
plt.title("平时冲动消费后后悔")
plt.show()
# Out:
# 购买后与购买前的期望有差距    75
# 以上情况均未出现过        48
# 觉得买贵了            35
# nan              25
# dtype: int64

# %%
#如何处理闲置商品
sep='┋'
test.split(sep)
all_item=sum(df['21、您一般如何处理这些不常使用的商品？'].fillna('nan').map(lambda x : x.split(sep)).values,[])
print(pd.DataFrame(all_item).value_counts()[1:])
fig = plt.figure()
axes1 = fig.add_subplot(1, 1, 1)
axes1.bar(pd.Series(all_item).value_counts().drop('nan').index,pd.Series(all_item).value_counts().drop('nan').values,color=colors)
plt.xticks(rotation=90,fontsize=9)
plt.title("如何处理闲置商品")
plt.show()
# Out:
# 闲置吃灰，以后或许有用    83
# 转手卖给他人         20
# 直接丢弃           14
# 慈善捐赠           10
# 租借给他人           7
# dtype: int64

# %%
#平时冲动消费区间
col='22、您的冲动消费行为常常发生在哪些价格区间'
colors = ['wheat', 'orange', 'gold', 'khaki','darkkhaki','olive']
sep='┋'
test.split(sep)
all_item=sum(df[col].fillna('nan').map(lambda x : x.split(sep)).values,[])
print(pd.DataFrame(all_item).value_counts()[1:])
fig = plt.figure()
axes1 = fig.add_subplot(1, 1, 1)
plt.pie(pd.Series(all_item).value_counts().drop('nan').values, labels=pd.Series(all_item).value_counts().drop('nan').index, colors=colors,autopct='%3.3f%%') 
plt.title('平时期间发生的冲动消费行为所在价格区间') 

plt.show()
# Out:
# 小于100元              72
# 大于等于200元且小于500元     47
# nan                 25
# 大于等于500元且小于1000元    17
# 大于等于1000元            7
# dtype: int64

# %%
df.to_csv('using.csv')

# %%
df
# Out:
#       序号               提交答卷时间    来源  来源详情 来自IP 1、双11的购物意愿  2、您在双11期间的消费金额为：  \
# 0      4   2022/11/25 9:43:09    微信   NaN   天津      较高于平时            小于100元
# 1      5   2022/11/25 9:50:42    微信   NaN   天津     没有消费意愿               NaN
# 2      6   2022/11/25 9:54:29    微信   NaN   北京      远高于平时         大于等于3000元
# 3      7   2022/11/25 9:56:14    微信   NaN   天津      与平时持平   大于等于100元且小于200元
# 4      8   2022/11/25 9:57:30    微信   NaN   天津     没有消费意愿               NaN
# ..   ...                  ...   ...   ...  ...        ...               ...
# 191  195  2022/11/27 18:14:36  手机提交  直接访问   天津      较高于平时   大于等于200元且小于500元
# 192  196  2022/11/27 18:15:39  手机提交  直接访问   天津      与平时持平   大于等于100元且小于200元
# 193  197  2022/11/27 18:18:30  手机提交  直接访问   天津     甚至不如平时            小于100元
# 194  198  2022/11/27 18:23:28  手机提交  直接访问   天津      与平时持平   大于等于200元且小于500元
# 195  199  2022/11/27 18:34:44  手机提交  直接访问   天津      远高于平时  大于等于500元且小于1000元
#
# ...

# %%
s1=df['提交答卷时间']
s2=df['22、您的冲动消费行为常常发生在哪些价格区间']
#建立两个数组
def getEntropy(s): #定义熵
    if not isinstance(s,pd.core.series.Series):
        s=pd.Series(s) #把不是数组的数据转化为数组
    prt_ary=s.value_counts()/float(len(s)) #得到概率分布
    return -(np.log2(prt_ary)*prt_ary).sum() #求和，得出熵
print('Entropy:',getEntropy(s1)) 
print('Entropy:',getEntropy(s2))
# Out:
# Entropy: 7.604505762482555
# Entropy: 2.6046219683324683

# %%
def getCondEntropy(s1,s2): #定义s1的条件s2的熵
    d=dict() #定义一个字典结构体
    for i in list(range(len(s1))):
        d[s1[i]]=d.get(s1[i],[])+[s2[i]] #key是s1的值，value是一个数组，为s2的值，记录了s1的值下s2的分布
    # print(d)
    return sum([getEntropy(d[k])*len(d[k])/float(len(s1)) for k in d])
print('CondEntropy',getCondEntropy(s1,s2)) #输出条件熵
# Out:
# CondEntropy 0.0

# %%
def getEntropyGain(s1,s2):
    return getEntropy(s2)-getCondEntropy(s1,s2) #s2的熵减s2条件下s1的熵
print('EntropyGain',getEntropyGain(s1,s2))
# Out:
# EntropyGain 2.6046219683324683

# %%
def getEntropyGainRatio(s1,s2):
    return  getEntropyGain(s1,s2)/getEntropy(s2) #熵增益除以熵
print('EntropyGainRatio',getEntropyGainRatio(s1,s2))
# Out:
# EntropyGainRatio 1.0

# %%
import math 
def getDiscreteCorr(s1,s2):
    return getEntropyGain(s1,s2)/math.sqrt(getEntropy(s1)*getEntropy(s2))
print('DiscreteCorr',getDiscreteCorr(s1,s2))
# Out:
# DiscreteCorr 0.585243842345471

# %% [markdown]
# 上面的貌似作用不大

# %%
matcor=pd.get_dummies(df[['2、您在双11期间的消费金额为：','3、您在双11期间购买的商品个数']]).corr()
import seaborn as sns
sns.heatmap(matcor)
# Out:
# <AxesSubplot: >

# %%
np.cov(df['填写时间'])
# Out:
# array(9876.38333333)

# %% [markdown]
# 下一步思路：
#
# - 区间型数据的处理：检验等等
# - 类别变量的方差分析
# - 多分类变量的相关性分析
